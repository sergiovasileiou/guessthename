# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %% [markdown]
# Here are some resources to learn about GDP:
# #### [World Bank](https://data.worldbank.org/indicator/ny.gdp.pcap.cd?most_recent_value_desc=false)
# #### [Our World in Data](https://ourworldindata.org/grapher/gdp-per-capita-worldbank)
# #### [IMF](https://www.imf.org/external/datamapper/NGDPD@WEO/OEMDC/ADVEC/WEOWORLD)
# #### [UN Data](https://data.un.org/Data.aspx?d=SNAAMA&f=grID%3A101%3BcurrID%3AUSD%3BpcFlag%3A1)

# %%
df = pd.read_csv("GDP (nominal) per Capita.csv",encoding= 'unicode_escape',  index_col=0)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Use this section to explore and inspect dataset.

# %%
#Dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223 entries, 1 to 223
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country/Territory   223 non-null    object
#  1   UN_Region           223 non-null    object
#  2   IMF_Estimate        223 non-null    int64
#  3   IMF_Year            223 non-null    int64
#  4   WorldBank_Estimate  223 non-null    int64
#  5   WorldBank_Year      223 non-null    int64
#  6   UN_Estimate         223 non-null    int64
#  7   UN_Year             223 non-null    object
# dtypes: int64(5), object(3)
# memory usage: 15.7+ KB

# %%
#Display the first few rows of the DataFrame
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5       NaN            234316.0
# 2     Liechtenstein    Europe      163507.5       NaN            157755.0
# 3        Luxembourg    Europe      132372.0    2023.0            133590.0
# 4           Ireland    Europe      114581.0    2023.0            100172.0
# 5           Bermuda  Americas      113371.5       NaN            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1          2021.0     234317.0    2021
# 2          2020.0     169260.0    2021
# 3          2021.0     133745.0    2021
# 4          2021.0     101109.0    2021
# 5          2021.0     112653.0    2021

# %%
#Get statistics for the DataFrame
df.describe()

# %%
#Counting the occurrences of each unique value in the 'UN_Region' column
df['UN_Region'].value_counts()
# Out:
# UN_Region
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: count, dtype: int64

# %%
#Filter the DataFrame to select rows where the 'UN_Region' is 'Europe'
df[df['UN_Region'] == 'Europe']
# Out:
#           Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 1                    Monaco    Europe      234316.5       NaN
# 2             Liechtenstein    Europe      163507.5       NaN
# 3                Luxembourg    Europe      132372.0    2023.0
# 4                   Ireland    Europe      114581.0    2023.0
# 6                    Norway    Europe      101103.0    2023.0
# 7               Switzerland    Europe       98767.0    2023.0
# 9               Isle of Man    Europe       87158.0       NaN
# 13                  Iceland    Europe       75180.0    2023.0
# 14          Channel Islands    Europe       75153.0       NaN
# 15            Faroe Islands    Europe       69010.0       NaN
# 16                  Denmark    Europe       68827.0    2023.0
# 18              Netherlands    Europe       61098.0    2023.0
# 20                  Austria    Europe       56802.0    2023.0
# 22                   Sweden    Europe       55395.0    2023.0
# ...

# %%
#Filter the DataFrame to select rows where the 'UN_Region' is 'Americas'
df[df['UN_Region'] == 'Americas']
# Out:
#                     Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 5                             Bermuda  Americas      113371.5       NaN
# 10                     Cayman Islands  Americas       85909.5       NaN
# 12                      United States  Americas       80034.0    2023.0
# 19                          Greenland  Americas       56378.0       NaN
# 26                             Canada  Americas       52722.0    2023.0
# 31             British Virgin Islands  Americas       49444.0       NaN
# 37                  US Virgin Islands  Americas       39552.0       NaN
# 38                        Puerto Rico  Americas       38567.0    2023.0
# 43                            Bahamas  Americas       35458.0    2023.0
# 50                              Aruba  Americas       33094.0    2023.0
# 58          Sint Maarten (Dutch part)  Americas       27593.5       NaN
# 65         Saint Martin (French part)  Americas       21921.0       NaN
# ...

# %%
#Filter the DataFrame to select rows where the 'UN_Region' is 'Africa'
df[df['UN_Region'] == 'Africa']
# Out:
#             Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 74                 Seychelles    Africa       19536.0    2023.0
# 101                 Mauritius    Africa       11548.0    2023.0
# 107         Equatorial Guinea    Africa        9777.0    2023.0
# 110                     Gabon    Africa        9294.0    2023.0
# 119                  Botswana    Africa        7270.0    2023.0
# 122                     Libya    Africa        6763.0    2023.0
# 125              South Africa    Africa        6485.0    2023.0
# 139                   Namibia    Africa        5100.0    2023.0
# 144                   Algeria    Africa        4481.0    2023.0
# 148                Cape Verde    Africa        4278.0    2023.0
# 150                  Eswatini    Africa        4146.0    2023.0
# 152                   Tunisia    Africa        4071.0    2023.0
# 154                  Djibouti    Africa        3802.0    2023.0
# 156                   Morocco    Africa        3748.0    2023.0
# ...

# %%
#Filter the DataFrame to select rows where the 'UN_Region' is 'Asia'
df[df['UN_Region'] == 'Asia']
# Out:
#         Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 8               Singapore      Asia       91100.0    2023.0
# 11                  Qatar      Asia       83891.0    2023.0
# 21                 Israel      Asia       55535.0    2023.0
# 27              Hong Kong      Asia       52429.0    2023.0
# 29                  Macau      Asia       50571.0    2023.0
# 30   United Arab Emirates      Asia       49451.0    2023.0
# 44                  Japan      Asia       35385.0    2023.0
# 45                 Brunei      Asia       35103.0    2023.0
# 46                 Taiwan      Asia       33907.0    2023.0
# 47                 Cyprus      Asia       33807.0    2023.0
# 48                 Kuwait      Asia       33646.0    2023.0
# 49            South Korea      Asia       33393.0    2023.0
# 55           Saudi Arabia      Asia       29922.0    2023.0
# 56                Bahrain      Asia       28385.0    2023.0
# 64                   Oman      Asia       21960.0    2023.0
# ...

# %%
#Filter the DataFrame to select rows where the 'UN_Region' is 'Oceania'
df[df['UN_Region'] == 'Oceania']
# Out:
#             Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 17                  Australia   Oceania       64964.0    2023.0
# 32                New Zealand   Oceania       48826.0    2023.0
# 39              New Caledonia   Oceania       36077.0       NaN
# 42                       Guam   Oceania       35905.0       NaN
# 61   Northern Mariana Islands   Oceania       23707.0       NaN
# 71           French Polynesia   Oceania       19915.0       NaN
# 76               Cook Islands   Oceania       19264.0       NaN
# 86             American Samoa   Oceania       15743.0       NaN
# 88                      Palau   Oceania       14804.0    2023.0
# 100                     Nauru   Oceania       11825.0    2023.0
# 130                    Tuvalu   Oceania        6007.0    2023.0
# 131                      Fiji   Oceania        5887.0    2023.0
# 135                     Tonga   Oceania        5421.0    2023.0
# 138          Marshall Islands   Oceania        5164.0    2023.0
# ...

# %%
# number of countries per region

# %%
region_counts = df['UN_Region'].value_counts().sort_values(ascending=False)
print(region_counts)
# Out:
# UN_Region
# Africa      55
# Asia        51
# Europe      48
# Americas    48
# Oceania     20
# World        1
# Name: count, dtype: int64

# %%
#What is European Union[n 1]?

# %%
df[df['Country/Territory'] == 'European Union[n 1]']
# Out:
#       Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 36  European Union[n 1]    Europe       39940.0    2023.0             38411.0
#
#     WorldBank_Year  UN_Estimate UN_Year
# 36          2021.0      31875.0    2021

# %%
# This  represents the aggregate GDP data for the European Union as a whole.
eu_data = df[df['Country/Territory'] == 'European Union[n 1]']
print(eu_data)
# Out:
#       Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 36  European Union[n 1]    Europe       39940.0    2023.0             38411.0
#
#     WorldBank_Year  UN_Estimate UN_Year
# 36          2021.0      31875.0    2021

# %%
# Countries in Europe below avarege

# %%
# Calculating the average GDP for Europe
europe_avg_gdp = df[df['UN_Region'] == 'Europe']['WorldBank_Estimate'].mean()
print('The average european GDP is', europe_avg_gdp,'!')
# Out:
# The average european GDP is 45193.6875 !

# %%
# Filtering countries in Europe with GDP below average
eu_countries_below_avg = df[(df['UN_Region'] == 'Europe') & (df['WorldBank_Estimate'] < europe_avg_gdp)]
# Removing non-relevant columns
eu_countries_below_avg = eu_countries_below_avg.drop(columns=['IMF_Year', 'UN_Region', 'WorldBank_Year', 'UN_Year'])
print(eu_countries_below_avg)
# Out:
#           Country/Territory  IMF_Estimate  WorldBank_Estimate  UN_Estimate
# 34                   France       44408.0             43659.0      44229.0
# 35                  Andorra       44387.0             42137.0      42066.0
# 36      European Union[n 1]       39940.0             38411.0      31875.0
# 40                    Malta       36989.0             33487.0      33642.0
# 41                    Italy       36812.0             35658.0      35579.0
# 51                 Slovenia       32214.0             29291.0      29135.0
# 52           Czech Republic       31368.0             26821.0      26809.0
# 53                    Spain       31223.0             30104.0      30058.0
# 54                  Estonia       31209.0             27944.0      27991.0
# 57                Lithuania       28094.0             23723.0      23844.0
# 59                 Portugal       26012.0             24568.0      24651.0
# ...

# %%
#Calculating the difference between the average GDP for Europe and the GDP of each country below average.
eu_countries_below_avg['GDP_Difference'] = europe_avg_gdp - eu_countries_below_avg['WorldBank_Estimate']
print(eu_countries_below_avg[['Country/Territory', 'WorldBank_Estimate', 'GDP_Difference']])
# Out:
#           Country/Territory  WorldBank_Estimate  GDP_Difference
# 34                   France             43659.0       1534.6875
# 35                  Andorra             42137.0       3056.6875
# 36      European Union[n 1]             38411.0       6782.6875
# 40                    Malta             33487.0      11706.6875
# 41                    Italy             35658.0       9535.6875
# 51                 Slovenia             29291.0      15902.6875
# 52           Czech Republic             26821.0      18372.6875
# 53                    Spain             30104.0      15089.6875
# 54                  Estonia             27944.0      17249.6875
# 57                Lithuania             23723.0      21470.6875
# 59                 Portugal             24568.0      20625.6875
# 60                   Latvia             21148.0      24045.6875
# 62                 Slovakia             21392.0      23801.6875
# 63                   Greece             20193.0      25000.6875
# ...

# %%
## Which countries in Europe has higher GDP than UK?

# %%
# Get the UK's GDP
uk_gdp = df[df['Country/Territory'] == 'United Kingdom']['WorldBank_Estimate'].values[0]
print('The GDP of the UK is', int(uk_gdp),'.')
# Out:
# The GDP of the UK is 46510 .

# %%
# Filter countries in Europe with higher GDP than UK
higher_gdp_countries = df[(df['UN_Region'] == 'Europe') & (df['WorldBank_Estimate'] > uk_gdp)]
print(higher_gdp_countries[['Country/Territory', 'WorldBank_Estimate']])
# Out:
#    Country/Territory  WorldBank_Estimate
# 1             Monaco            234316.0
# 2      Liechtenstein            157755.0
# 3         Luxembourg            133590.0
# 4            Ireland            100172.0
# 6             Norway             89154.0
# 7        Switzerland             91992.0
# 9        Isle of Man             87158.0
# 13           Iceland             68728.0
# 14   Channel Islands             75153.0
# 15     Faroe Islands             69010.0
# 16           Denmark             68008.0
# 18       Netherlands             57768.0
# 20           Austria             53638.0
# 22            Sweden             61029.0
# 23           Finland             53655.0
# 24           Belgium             51247.0
# 28           Germany             51204.0

# %%
 #Get GDP values for EU, UK, and global average
eu_gdp = df[df['Country/Territory'] == 'European Union[n 1]']['WorldBank_Estimate'].values[0]
uk_gdp = df[df['Country/Territory'] == 'United Kingdom']['WorldBank_Estimate'].values[0]
global_avg_gdp = df['WorldBank_Estimate'].mean()

print("European Union GDP:", eu_gdp)
print("United Kingdom GDP:", uk_gdp)
print("Global Average GDP:", global_avg_gdp)
# Out:
# European Union GDP: 38411.0
# United Kingdom GDP: 46510.0
# Global Average GDP: 19540.805555555555

# %% [markdown]
# ## groupby()

# %% [markdown]
# [Learn more about groupby](https://www.geeksforgeeks.org/pandas-groupby/)

# %%
# Get descriptive statistics for each UN Region
region_stats = df.groupby('UN_Region')['WorldBank_Estimate'].describe()

# Sort the regions based on the 'mean' value in ascending order
region_stats_sorted = region_stats.sort_values(by='mean', ascending=True)

# Display the sorted descriptive statistics
print(region_stats_sorted)
# Out:
#            count          mean           std      min       25%      50%  \
# UN_Region
# Africa      54.0   2516.592593   2777.439716    222.0    777.75   1448.5
# World        1.0  12235.000000           NaN  12235.0  12235.00  12235.0
# Asia        49.0  14489.530612  18557.803108    369.0   2536.00   4775.0
# Oceania     19.0  15909.105263  17516.033826   1607.0   3714.00   6172.0
# Americas    45.0  19802.800000  22994.593423   1830.0   6228.00  10636.0
# Europe      48.0  45193.687500  43984.130016   4836.0  16978.25  31795.5
#
#                 75%       max
# UN_Region
# Africa      3257.25   14653.0
# World      12235.00   12235.0
# Asia       23186.00   72794.0
# Oceania    21811.00   60443.0
# Americas   20909.00  114090.0
# Europe     58583.25  234316.0

# %%
#Grouping by the year
year_avg_gdp = df.groupby('WorldBank_Year')['WorldBank_Estimate'].mean()
#Converting numbers to integers
year_avg_gdp=datatype = year_avg_gdp.astype(int)
print(year_avg_gdp)
# Out:
# WorldBank_Year
# 2007.0    75153
# 2011.0      644
# 2014.0    18948
# 2015.0     1072
# 2018.0    14845
# 2019.0    39403
# 2020.0    47361
# 2021.0    18224
# Name: WorldBank_Estimate, dtype: int64

# %%
#Grouping by year and region, excluding year 0
year_region_gdp = df[df['WorldBank_Year'] != 0].groupby(['WorldBank_Year', 'UN_Region'])['WorldBank_Estimate'].mean()
# Convert to integers
year_region_gdp = year_region_gdp.astype(int)
print(year_region_gdp)
# Out:
# WorldBank_Year  UN_Region
# 2007.0          Europe        75153
# 2011.0          Africa          644
# 2014.0          Americas      18948
# 2015.0          Africa         1072
# 2018.0          Americas      28988
#                 Asia            702
# 2019.0          Asia           7345
#                 Europe        87158
#                 Oceania       23707
# 2020.0          Americas      34541
#                 Asia          12416
#                 Europe       101537
# 2021.0          Africa         2580
#                 Americas      18477
#                 Asia          15046
#                 Europe        40997
#                 Oceania       15475
#                 World         12235
# Name: WorldBank_Estimate, dtype: int64

# %%
# Grouping countries that have "land" in their name
land_countries = df[df['Country/Territory'].str.contains('land')]
land_countries_gdp = land_countries.groupby('Country/Territory')['WorldBank_Estimate'].mean()

print(land_countries_gdp)
# Out:
# Country/Territory
# British Virgin Islands           NaN
# Cayman Islands               86569.0
# Channel Islands              75153.0
# Cook Islands                     NaN
# Faroe Islands                69010.0
# Finland                      53655.0
# Greenland                    54571.0
# Iceland                      68728.0
# Ireland                     100172.0
# Marshall Islands              6172.0
# Netherlands                  57768.0
# New Zealand                  48781.0
# Northern Mariana Islands     23707.0
# Poland                       18000.0
# Solomon Islands               2305.0
# Switzerland                  91992.0
# Thailand                      7066.0
# Turks and Caicos Islands     20909.0
# US Virgin Islands            39552.0
# Name: WorldBank_Estimate, dtype: float64

# %% [markdown]
# ## Which countries below average by IMF world estimate?

# %%
# Calculate the global average IMF estimate
global_avg_imf = df['IMF_Estimate'].mean()

#Showing the global average as a whole number
print('Global Average IMF:', int(global_avg_imf))

# Filter-out countries with IMF = 0
below_avg_imf_countries = df[(df['IMF_Estimate'] != 0) & (df['IMF_Estimate'] < global_avg_imf)]

#Sorting the results by descending order
below_avg_imf_countries = below_avg_imf_countries.sort_values(by='IMF_Estimate', ascending=False)
print(below_avg_imf_countries[['Country/Territory', 'IMF_Estimate']])
# Out:
# Global Average IMF: 20998
#             Country/Territory  IMF_Estimate
# 68   Turks and Caicos Islands       20909.0
# 69                     Guyana       20539.0
# 70                    Croatia       20537.0
# 71           French Polynesia       19915.0
# 72                     Poland       19912.0
# ..                        ...           ...
# 218  Central African Republic         534.0
# 219                    Malawi         496.0
# 220               South Sudan         467.0
# 221              Sierra Leone         415.0
# 223                   Burundi         249.0
#
# [156 rows x 2 columns]

# %% [markdown]
# ### IMF estimate 0 values

# %%
#Identifying countries with 0 IMF estimates:
zero_imf_countries = df[df['IMF_Estimate'] == 0]
print(zero_imf_countries[['Country/Territory', 'IMF_Estimate']])
# Out:
#               Country/Territory  IMF_Estimate
# 1                        Monaco             0
# 2                 Liechtenstein             0
# 5                       Bermuda             0
# 9                   Isle of Man             0
# 10               Cayman Islands             0
# 14              Channel Islands             0
# 15                Faroe Islands             0
# 19                    Greenland             0
# 31       British Virgin Islands             0
# 37            US Virgin Islands             0
# 39                New Caledonia             0
# 42                         Guam             0
# 58    Sint Maarten (Dutch part)             0
# 61     Northern Mariana Islands             0
# 65   Saint Martin (French part)             0
# 68     Turks and Caicos Islands             0
# 71             French Polynesia             0
# 76                 Cook Islands             0
# 77                     Anguilla             0
# ...

# %% [markdown]
# ## Which country has highest UN Estimate?

# %%
# Find the index of the row with the maximum UN_Estimate
max_un_estimate_index = df['UN_Estimate'].idxmax()

# Get the country name and the highest UN estimate value
country_with_highest_un_estimate = df.loc[max_un_estimate_index, 'Country/Territory']
highest_un_estimate = df.loc[max_un_estimate_index, 'UN_Estimate']

print(f"The country with the highest UN estimate is: {country_with_highest_un_estimate} with an estimate of {highest_un_estimate}")
# Out:
# The country with the highest UN estimate is: Monaco with an estimate of 234317.0

# %% [markdown]
# ## Which country has highest Worlbank Estimate?

# %%
# Find the index of the row with the maximum WorldBank_Estimate
max_worldbank_estimate_index = df['WorldBank_Estimate'].idxmax()

# Get the country name and the highest World Bank estimate value
country_with_highest_worldbank_estimate = df.loc[max_worldbank_estimate_index, 'Country/Territory']
highest_worldbank_estimate = df.loc[max_worldbank_estimate_index, 'WorldBank_Estimate']

print(f"The country with the highest World Bank estimate is: {country_with_highest_worldbank_estimate} with an estimate of {highest_worldbank_estimate}")
# Out:
# The country with the highest World Bank estimate is: Monaco with an estimate of 234316.0

# %% [markdown]
# ## Which country has highest IMF Estimate?

# %%
# Find the index of the row with the maximum IMF_Estimate
max_imf_estimate_index = df['IMF_Estimate'].idxmax()

# Get the country name and the highest IMF estimate value
country_with_highest_un_estimate = df.loc[max_imf_estimate_index, 'Country/Territory']
highest_imf_estimate = df.loc[max_imf_estimate_index, 'IMF_Estimate']

print(f"The country with the highest IMF estimate is: {country_with_highest_un_estimate} with an estimate of {highest_imf_estimate}")
# Out:
# The country with the highest IMF estimate is: Luxembourg with an estimate of 132372

# %% [markdown]
# ## Filling 0 Values by average

# %%
import numpy as np

# %%
# replace 0 with null values

# %%
df.replace(0, np.nan, inplace=True)

# %%
# Calculate the average of 'Worldbank_Estimate' and 'UN_Estimate' columns
df['avg_worldbank_un'] = df[['WorldBank_Estimate', 'UN_Estimate']].mean(axis=1)

# %%
# Fill the null values in 'imf' column with the calculated average
df['IMF_Estimate'] = df['IMF_Estimate'].fillna(avg_worldbank_un)

# %%
# Drop the temporary 'avg_worldbank_un' column if not needed
df.drop(columns=['avg_worldbank_un'], inplace=True)

# %%
print(df.head())
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5       NaN            234316.0
# 2     Liechtenstein    Europe      163507.5       NaN            157755.0
# 3        Luxembourg    Europe      132372.0    2023.0            133590.0
# 4           Ireland    Europe      114581.0    2023.0            100172.0
# 5           Bermuda  Americas      113371.5       NaN            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1          2021.0     234317.0    2021
# 2          2020.0     169260.0    2021
# 3          2021.0     133745.0    2021
# 4          2021.0     101109.0    2021
# 5          2021.0     112653.0    2021

# %% [markdown]
# [Visit this link to learn more about ffill](https://www.w3schools.com/python/pandas/ref_df_ffill.asp)

# %% [markdown]
# [Visit this link to learn more about bfill](https://www.w3schools.com/python/pandas/ref_df_bfill.asp)

# %% [markdown]
# ## Checking Missing Values

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Country/Territory      0
# UN_Region              0
# IMF_Estimate           0
# IMF_Year              26
# WorldBank_Estimate     7
# WorldBank_Year         7
# UN_Estimate            9
# UN_Year                0
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=5, figsize=(12,9))

plt.show()

# %%
df["WorldBank_Estimate"].agg(["min","max"])
# Out:
# min       222.0
# max    234316.0
# Name: WorldBank_Estimate, dtype: float64

# %%
234316/5
#1 bin size if bins=5
# Out:
# 46863.2

# %%
df[df["WorldBank_Estimate"]<=46863.2]["WorldBank_Estimate"].count()
# Out:
# 188

# %%
234316/10
#1 bin size if bins not given any number
# Out:
# 23431.6

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=3, figsize=(12,9))

plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))

#23400/15 = 15300
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()
# Out:
#                     IMF_Estimate  UN_Estimate  WorldBank_Estimate
# IMF_Estimate            1.000000     0.994977            0.995517
# UN_Estimate             0.994977     1.000000            0.998438
# WorldBank_Estimate      0.995517     0.998438            1.000000

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))
sns.heatmap(corr)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, fmt=".2f", cmap = 'GnBu', annot_kws={"size": 12})

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %%
corr = df.select_dtypes(include=[int, float]).corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5       NaN            234316.0
# 2     Liechtenstein    Europe      163507.5       NaN            157755.0
# 3        Luxembourg    Europe      132372.0    2023.0            133590.0
# 4           Ireland    Europe      114581.0    2023.0            100172.0
# 5           Bermuda  Americas      113371.5       NaN            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1          2021.0     234317.0    2021
# 2          2020.0     169260.0    2021
# 3          2021.0     133745.0    2021
# 4          2021.0     101109.0    2021
# 5          2021.0     112653.0    2021

# %%
sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=df, errorbar=None)

plt.show()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, errorbar=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",
data = df, errorbar = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate",
                 data = df, errorbar = None)

ax.bar_label(ax.containers[0])


ax.set_title("Regions by IMF Estimate")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
df.plot(x='UN_Region', y='UN_Estimate', kind='scatter',
        figsize=(10,6),
        title="Scatter Plot")
# ... (previous code with color-coding or marker size) ...
plt.show()

# %%
# World Bank Estimate vs. IMF Estimate
df.plot(x='WorldBank_Estimate', y='IMF_Estimate', kind='scatter',
        figsize=(10, 6),
        title="World Bank Estimate vs. IMF Estimate")
plt.show()

# %%
#World Bank Estimate vs. UN Estimate:
df.plot(x='WorldBank_Estimate', y='UN_Estimate', kind='scatter',
        figsize=(10, 6),
        title="World Bank Estimate vs. UN Estimate")
plt.show()

# %%
#IMF Estimate vs. UN Estimate:
df.plot(x='IMF_Estimate', y='UN_Estimate', kind='scatter',
        figsize=(10, 6),
        title="IMF Estimate vs. UN Estimate")
plt.show()

# %% [markdown]
# ### Boxplot and Outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>50000].head()
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5       NaN            234316.0
# 2     Liechtenstein    Europe      163507.5       NaN            157755.0
# 3        Luxembourg    Europe      132372.0    2023.0            133590.0
# 4           Ireland    Europe      114581.0    2023.0            100172.0
# 5           Bermuda  Americas      113371.5       NaN            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1          2021.0     234317.0    2021
# 2          2020.0     169260.0    2021
# 3          2021.0     133745.0    2021
# 4          2021.0     101109.0    2021
# 5          2021.0     112653.0    2021

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]
# Out:
#   Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 1            Monaco    Europe      234316.5       NaN            234316.0
# 2     Liechtenstein    Europe      163507.5       NaN            157755.0
# 3        Luxembourg    Europe      132372.0    2023.0            133590.0
# 4           Ireland    Europe      114581.0    2023.0            100172.0
# 5           Bermuda  Americas      113371.5       NaN            114090.0
#
#    WorldBank_Year  UN_Estimate UN_Year
# 1          2021.0     234317.0    2021
# 2          2020.0     169260.0    2021
# 3          2021.0     133745.0    2021
# 4          2021.0     101109.0    2021
# 5          2021.0     112653.0    2021

# %%
df.UN_Estimate.mean()
# Out:
# 18514.528037383177

# %%
df.shape
# Out:
# (223, 8)

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()
# Out:
#    Country/Territory UN_Region  IMF_Estimate  IMF_Year  WorldBank_Estimate  \
# 6             Norway    Europe      101103.0    2023.0             89154.0
# 7        Switzerland    Europe       98767.0    2023.0             91992.0
# 8          Singapore      Asia       91100.0    2023.0             72794.0
# 9        Isle of Man    Europe       87158.0       NaN             87158.0
# 10    Cayman Islands  Americas       85909.5       NaN             86569.0
#
#     WorldBank_Year  UN_Estimate UN_Year
# 6           2021.0      89242.0    2021
# 7           2021.0      93525.0    2021
# 8           2021.0      66822.0    2021
# 9           2019.0          NaN       0
# 10          2021.0      85250.0    2021

# %%
data.shape
# Out:
# (218, 8)

# %%
data.UN_Estimate.mean()
# Out:
# 15363.755980861244

# %%
df.UN_Estimate.mean()
# Out:
# 18514.528037383177

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q
# Out:
# 2331.75

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q
# Out:
# 21359.25

# %%
iqr = higher_q - lower_q
iqr
# Out:
# 19027.5

# %%
upper_boundary = higher_q + 1.5 * iqr
upper_boundary
# Out:
# 49900.5

# %%
lower_boundary = lower_q - 1.5 * iqr
lower_boundary
# Out:
# -26209.5

# %%
df_filtered = df[(df["UN_Estimate"] < upper_boundary) & (df["UN_Estimate"] > lower_boundary)]

# %%
df_filtered.head()
# Out:
#          Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 27               Hong Kong      Asia       52429.0    2023.0
# 29                   Macau      Asia       50571.0    2023.0
# 30    United Arab Emirates      Asia       49451.0    2023.0
# 31  British Virgin Islands  Americas       49444.0       NaN
# 32             New Zealand   Oceania       48826.0    2023.0
#
#     WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 27             49801.0          2021.0      49259.0    2021
# 29             43874.0          2021.0      43555.0    2021
# 30             44316.0          2021.0      43295.0    2021
# 31                 NaN             NaN      49444.0    2021
# 32             48781.0          2021.0      48824.0    2021

# %%
df_filtered.shape
# there were 223 rows - 196 = 27 outliers dropped
# Out:
# (190, 8)

# %%
df_filtered.UN_Estimate.mean()
# Out:
# 10488.947368421053

# %%
df.UN_Estimate.mean()
# Out:
# 18514.528037383177

# %%
#how can we create a table with following
df_filtered.WorldBank_Estimate.mean()
# Out:
# 10355.304347826086

# %%
df.WorldBank_Estimate.mean()
# Out:
# 19540.805555555555

# %%
df_filtered.IMF_Estimate.mean()
# Out:
# 11697.976315789474

# %%
df.IMF_Estimate.mean()
# Out:
# 20998.14125560538
